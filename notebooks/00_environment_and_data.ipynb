# %% [markdown]
# # 00 — Environment and data
# Goal: inspect the observation → action → next observation contract before training.
# Select the World Models kernel after following README setup.

# %%
import world_models
print(world_models.__version__)

# %% [markdown]
# ## Your first implementation task
# 1. Construct the environment with explicit settings and seed.
# 2. Collect a complete episode preserving the final observation.
# 3. Display consecutive frames and the action between them.
# 4. Check T actions correspond to T+1 observations.
# 5. Record episode metadata and split by episode.
#
# Before coding: why would pairing action[t] with observation[t+1] as its input silently damage memory training?
